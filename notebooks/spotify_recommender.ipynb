# %%
import requests
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
cid = '74a88342b13c4acfb29d53ba0b8a2540'
secret = '52c115ad7ecf4c76974e6341fd02f003'

#Authentication 
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/4XhkvMbp57gf2QpZPwPq3z"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
playlist = sp.user_playlist_tracks('spotify', '4XhkvMbp57gf2QpZPwPq3z') 
songs = playlist['items']
df = pd.DataFrame(songs)
print(df.columns)
df.to_csv('Songs.csv', sep=';', encoding='utf-8', index=True)
# Out:
# Index(['added_at', 'added_by', 'is_local', 'primary_color', 'track',
#        'video_thumbnail'],
#       dtype='object')

# %%
artist_name =list()
track_name=list()
track_id =list()
popularity = list()
genres = list()
nb_followers = list()
album = list()
track_uri= []
user_id=[]
for i, item in enumerate(playlist['items']):
    track = item['track']
    #Main Artist
    artist_uri = track["artists"][0]["uri"]
    #song_df["artist_uri"][i] = artist_uri
    artist_info = sp.artist(artist_uri)
    #print(artist_info)
    artist_name.append(track['artists'][0]['name'])
    track_name.append(track['name'])
    track_id.append(track['id'])
    popularity.append(track['popularity'])
    genres.append(artist_info['genres'])
    nb_followers.append(artist_info["followers"]["total"])
    album.append(track["album"]["name"])
    track_uri.append(track["uri"])
    user_id.append(1194339014)


song_df = pd.DataFrame({'user_id' : user_id,'artist_name':artist_name,'track_name':track_name,'track_id':track_id, 
'popularity':popularity, 'genres':genres, "nb_followers":nb_followers, "album": album, 
"track_uri":track_uri, "audio_features": sp.audio_features(track_uri)})

# %%
song_df
# Out:
#        user_id     artist_name  \
# 0   1194339014         Mahalia
# 1   1194339014         Kranium
# 2   1194339014         Ayo Jay
# 3   1194339014            Ashe
# 4   1194339014            Ashe
# ..         ...             ...
# 91  1194339014  Kevin Abstract
# 92  1194339014          Choker
# 93  1194339014            Saba
# 94  1194339014           Swing
# 95  1194339014            Irma
#
#                                            track_name                track_id  \
# 0                                               Sober  3C57ewlHARCVqeH3KiYkma
# 1            Nobody Has to Know (feat. Ty Dolla $ign)  4J6D5TFiE1H7pLebgSx9Fj
# 2                           10 Over 10 (feat. Rotimi)  4eMq3u4vIWoofiziFBTV1j
# 3   Cold in California ft. Gavin Haley (Live at Vevo)  0M0egTRZPqXAnVMSFiXKia
# 4                     In Disguise (OurVinyl Sessions)  34IeyucGOFXPY6R1uofj8W
# ..                                                ...                     ...
# 91                                            Crumble  3ls9lmPJ7xROR2VL5Kv1Gz
# 92                                               Juno  6OpU3cvY19M2hFxTbLKy5L
# 93                               HEAVEN ALL AROUND ME  7o2IbwyONZhbwYmjYXtTF4
# 94                                         S'en aller  5Ea38RCmV570c6Sj4EUqIq
# 95                                             I Know  1xpoDN9hMZADv8ZRdZIeas
#
#     popularity                                             genres  \
# 0           58  [alternative r&b, indie anthem-folk, pop, r&b,...
# 1           46                              [basshall, dancehall]
# 2           54                                        [dancehall]
# 3           30                           [alt z, electropop, pop]
# 4            0                           [alt z, electropop, pop]
# ..         ...                                                ...
# 91          51  [afrofuturism, alternative r&b, hip hop, lgbtq...
# 92          59           [alternative r&b, indie r&b, indie soul]
# 93          52  [alternative r&b, chicago rap, hip hop, rap, u...
# 94          51       [belgian hip hop, french hip hop, rap calme]
# 95          55                     [french indie pop, french pop]
#
#     nb_followers                                              album  \
# 0         752421                                              Sober
# 1         162919           Nobody Has to Know (feat. Ty Dolla $ign)
# 2         110217                                        Lazy Genius
# 3        1105540  Cold in California ft. Gavin Haley (Live at Vevo)
# 4        1105540                           Ashe | OurVinyl Sessions
# ..           ...                                                ...
# 91        670980                                       ARIZONA BABY
# 92        181327                                         Honeybloom
# 93        602380                                        CARE FOR ME
# 94        101195                                             ALT F4
# 95         59116                                 Letter to the Lord
#
#                                track_uri  \
# 0   spotify:track:3C57ewlHARCVqeH3KiYkma
# 1   spotify:track:4J6D5TFiE1H7pLebgSx9Fj
# 2   spotify:track:4eMq3u4vIWoofiziFBTV1j
# 3   spotify:track:0M0egTRZPqXAnVMSFiXKia
# 4   spotify:track:34IeyucGOFXPY6R1uofj8W
# ..                                   ...
# 91  spotify:track:3ls9lmPJ7xROR2VL5Kv1Gz
# 92  spotify:track:6OpU3cvY19M2hFxTbLKy5L
# 93  spotify:track:7o2IbwyONZhbwYmjYXtTF4
# 94  spotify:track:5Ea38RCmV570c6Sj4EUqIq
# 95  spotify:track:1xpoDN9hMZADv8ZRdZIeas
#
#                                        audio_features
# 0   {'danceability': 0.657, 'energy': 0.7, 'key': ...
# 1   {'danceability': 0.749, 'energy': 0.716, 'key'...
# 2   {'danceability': 0.913, 'energy': 0.399, 'key'...
# 3   {'danceability': 0.523, 'energy': 0.187, 'key'...
# 4   {'danceability': 0.442, 'energy': 0.159, 'key'...
# ..                                                ...
# 91  {'danceability': 0.571, 'energy': 0.553, 'key'...
# 92  {'danceability': 0.438, 'energy': 0.266, 'key'...
# 93  {'danceability': 0.678, 'energy': 0.393, 'key'...
# 94  {'danceability': 0.814, 'energy': 0.422, 'key'...
# 95  {'danceability': 0.753, 'energy': 0.494, 'key'...
#
# [96 rows x 10 columns]

# %% [markdown]
# ## Popularity

# %%
import Recommenders as Recommenders
train_data, test_data = train_test_split(song_df, test_size = 0.20, random_state=0)
print(train_data)
pm = Recommenders.popularity_recommender_py()
pm.create(train_data, 'user_id', 'track_name')
users = song_df['user_id'].unique()
user_id = users[0]
recom = pm.recommend(user_id)
print(recom)
# Out:
#        user_id     artist_name  \
# 43  1194339014          Skepta
# 62  1194339014      Kali Uchis
# 3   1194339014            Ashe
# 86  1194339014       Kelsey Lu
# 45  1194339014         Jok'air
# ..         ...             ...
# 92  1194339014          Choker
# 67  1194339014      Kali Uchis
# 64  1194339014      Kali Uchis
# 47  1194339014  Terrace Martin
# 44  1194339014          Twista
#
#                                            track_name                track_id  \
# 43                             Energy (Stay Far Away)  11RIJRbBfyLlJut96itSFd
# 62                                  la luna enamorada  2nDLZMuPMvHzNtUY2e7nV3
# 3   Cold in California ft. Gavin Haley (Live at Vevo)  0M0egTRZPqXAnVMSFiXKia
# 86                                           Due West  1EvFahLuLZ0vSVZo8YR3G9
# 45                 Elles ont trop joué avec mon coeur  6D5IVTqitCPC0bUJqENGuD
# ..                                                ...                     ...
# 92                                               Juno  6OpU3cvY19M2hFxTbLKy5L
# 67                               quiero sentirme bien  1xP2jdihnPfoqPNVHHhKnm
# 64                       //aguardiente y limón %ᵕ‿‿ᵕ%  0Ui4S8sgBCXv4Ao1HhTTun
# 47  Drones (feat. Kendrick Lamar, Snoop Dogg, Ty D...  3zdsJOO5FIAgukJUMgboV8
# 44                                          Slow Jamz  3A4cpTBPaIQdtPFb5JxtaX
#
#     popularity                                             genres  \
# 43          65  [birmingham grime, grime, instrumental grime, ...
# 62          59                    [colombian pop, dance pop, pop]
# 3           30                           [alt z, electropop, pop]
# 86          45  [alternative r&b, art pop, escape room, experi...
# 45          60  [french hip hop, pop urbaine, rap calme, rap f...
# ..         ...                                                ...
# 92          59           [alternative r&b, indie r&b, indie soul]
# 67          61                    [colombian pop, dance pop, pop]
# 64          58                    [colombian pop, dance pop, pop]
# 47          44            [alternative r&b, indie soul, neo soul]
# 44          72  [chicago rap, dirty south rap, gangster rap, h...
#
#     nb_followers                                              album  \
# 43       1036348                             Energy (Stay Far Away)
# 62       2963777            Sin Miedo (del Amor y Otros Demonios) ∞
# 3        1105540  Cold in California ft. Gavin Haley (Live at Vevo)
# 86        118472                                              Blood
# 45        785331                         Jok'Chirac (VI republique)
# ..           ...                                                ...
# 92        181327                                         Honeybloom
# 67       2963777            Sin Miedo (del Amor y Otros Demonios) ∞
# 64       2963777            Sin Miedo (del Amor y Otros Demonios) ∞
# 47        122446                                             DRONES
# 44        850282                                The College Dropout
#
#                                track_uri  \
# 43  spotify:track:11RIJRbBfyLlJut96itSFd
# 62  spotify:track:2nDLZMuPMvHzNtUY2e7nV3
# 3   spotify:track:0M0egTRZPqXAnVMSFiXKia
# 86  spotify:track:1EvFahLuLZ0vSVZo8YR3G9
# 45  spotify:track:6D5IVTqitCPC0bUJqENGuD
# ..                                   ...
# 92  spotify:track:6OpU3cvY19M2hFxTbLKy5L
# 67  spotify:track:1xP2jdihnPfoqPNVHHhKnm
# 64  spotify:track:0Ui4S8sgBCXv4Ao1HhTTun
# 47  spotify:track:3zdsJOO5FIAgukJUMgboV8
# 44  spotify:track:3A4cpTBPaIQdtPFb5JxtaX
#
#                                        audio_features
# 43  {'danceability': 0.836, 'energy': 0.614, 'key'...
# 62  {'danceability': 0.529, 'energy': 0.239, 'key'...
# 3   {'danceability': 0.523, 'energy': 0.187, 'key'...
# 86  {'danceability': 0.429, 'energy': 0.545, 'key'...
# 45  {'danceability': 0.686, 'energy': 0.565, 'key'...
# ..                                                ...
# 92  {'danceability': 0.438, 'energy': 0.266, 'key'...
# 67  {'danceability': 0.779, 'energy': 0.38, 'key':...
# 64  {'danceability': 0.785, 'energy': 0.477, 'key'...
# 47  {'danceability': 0.758, 'energy': 0.619, 'key'...
# 44  {'danceability': 0.559, 'energy': 0.733, 'key'...
#
# [76 rows x 10 columns]
#       user_id                       track_name  score  Rank
# 0  1194339014     //aguardiente y limón %ᵕ‿‿ᵕ%      1   1.0
# 1  1194339014                        2 The Sky      1   2.0
# 2  1194339014                 Add the Bassline      1   3.0
# 3  1194339014                      Ancient One      1   4.0
# 4  1194339014                       Ask Myself      1   5.0
# 5  1194339014  Back Home (feat. Summer Walker)      1   6.0
# 6  1194339014                  Beautiful Loser      1   7.0
# 7  1194339014                     Between Days      1   8.0
# 8  1194339014                  Big Momma Thang      1   9.0
# 9  1194339014                       Body Party      1  10.0

# %% [markdown]
# ## Item similarity

# %%
import Recommenders as Recommenders
train_data, test_data = train_test_split(song_df, test_size = 0.20, random_state=0)
print(train_data)
pm = Recommenders.item_similarity_recommender_py()
pm.create(train_data, 'user_id', 'track_name')
users = song_df['user_id'].unique()
user_id = users[0]
print(pm.recommend(user_id))
# Out:
#        user_id     artist_name  \
# 43  1194339014          Skepta
# 62  1194339014      Kali Uchis
# 3   1194339014            Ashe
# 86  1194339014       Kelsey Lu
# 45  1194339014         Jok'air
# ..         ...             ...
# 92  1194339014          Choker
# 67  1194339014      Kali Uchis
# 64  1194339014      Kali Uchis
# 47  1194339014  Terrace Martin
# 44  1194339014          Twista
#
#                                            track_name                track_id  \
# 43                             Energy (Stay Far Away)  11RIJRbBfyLlJut96itSFd
# 62                                  la luna enamorada  2nDLZMuPMvHzNtUY2e7nV3
# 3   Cold in California ft. Gavin Haley (Live at Vevo)  0M0egTRZPqXAnVMSFiXKia
# 86                                           Due West  1EvFahLuLZ0vSVZo8YR3G9
# 45                 Elles ont trop joué avec mon coeur  6D5IVTqitCPC0bUJqENGuD
# ..                                                ...                     ...
# 92                                               Juno  6OpU3cvY19M2hFxTbLKy5L
# 67                               quiero sentirme bien  1xP2jdihnPfoqPNVHHhKnm
# 64                       //aguardiente y limón %ᵕ‿‿ᵕ%  0Ui4S8sgBCXv4Ao1HhTTun
# 47  Drones (feat. Kendrick Lamar, Snoop Dogg, Ty D...  3zdsJOO5FIAgukJUMgboV8
# 44                                          Slow Jamz  3A4cpTBPaIQdtPFb5JxtaX
#
#     popularity                                             genres  \
# 43          65  [birmingham grime, grime, instrumental grime, ...
# 62          59                    [colombian pop, dance pop, pop]
# 3           29                           [alt z, electropop, pop]
# 86          45  [alternative r&b, art pop, escape room, experi...
# 45          60  [french hip hop, pop urbaine, rap calme, rap f...
# ..         ...                                                ...
# 92          59           [alternative r&b, indie r&b, indie soul]
# 67          61                    [colombian pop, dance pop, pop]
# 64          58                    [colombian pop, dance pop, pop]
# 47          44                      [alternative r&b, indie soul]
# 44          72  [chicago rap, dirty south rap, gangster rap, h...
#
#     nb_followers                                              album  \
# 43       1036064                             Energy (Stay Far Away)
# 62       2961037            Sin Miedo (del Amor y Otros Demonios) ∞
# 3        1104154  Cold in California ft. Gavin Haley (Live at Vevo)
# 86        118426                                              Blood
# 45        784765                         Jok'Chirac (VI republique)
# ..           ...                                                ...
# 92        181248                                         Honeybloom
# 67       2961037            Sin Miedo (del Amor y Otros Demonios) ∞
# 64       2961037            Sin Miedo (del Amor y Otros Demonios) ∞
# 47        122406                                             DRONES
# 44        850030                                The College Dropout
#
#                                track_uri  \
# 43  spotify:track:11RIJRbBfyLlJut96itSFd
# 62  spotify:track:2nDLZMuPMvHzNtUY2e7nV3
# 3   spotify:track:0M0egTRZPqXAnVMSFiXKia
# 86  spotify:track:1EvFahLuLZ0vSVZo8YR3G9
# 45  spotify:track:6D5IVTqitCPC0bUJqENGuD
# ..                                   ...
# 92  spotify:track:6OpU3cvY19M2hFxTbLKy5L
# 67  spotify:track:1xP2jdihnPfoqPNVHHhKnm
# 64  spotify:track:0Ui4S8sgBCXv4Ao1HhTTun
# 47  spotify:track:3zdsJOO5FIAgukJUMgboV8
# 44  spotify:track:3A4cpTBPaIQdtPFb5JxtaX
#
#                                        audio_features
# 43  {'danceability': 0.836, 'energy': 0.614, 'key'...
# 62  {'danceability': 0.529, 'energy': 0.239, 'key'...
# 3   {'danceability': 0.523, 'energy': 0.187, 'key'...
# 86  {'danceability': 0.429, 'energy': 0.545, 'key'...
# 45  {'danceability': 0.686, 'energy': 0.565, 'key'...
# ..                                                ...
# 92  {'danceability': 0.438, 'energy': 0.266, 'key'...
# 67  {'danceability': 0.779, 'energy': 0.38, 'key':...
# 64  {'danceability': 0.785, 'energy': 0.477, 'key'...
# 47  {'danceability': 0.758, 'energy': 0.619, 'key'...
# 44  {'danceability': 0.559, 'energy': 0.733, 'key'...
#
# [76 rows x 10 columns]
